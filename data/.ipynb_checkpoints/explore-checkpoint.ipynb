# %%
from functional import seq
import json
import re

# %%
recipes = seq.open("recipes-raw.jsonl", encoding="utf-8").map(json.loads)

# %%
titles = recipes.map(lambda x: x['title'])

# %%
ingredients = recipes.map(lambda x: x['ingredients']).flatten()
ingredients.take(1)
# Out:
# ['1 tablespoon vegetable oil, divided']

# %%
unit_names = ["\)","teaspoon", "tablespoon", "pound", "ounce", "pinch", "cup", "pint", "quart", "drop", "gallon"]
unit_regex = re.compile("(" + "|".join(unit_names) + ")[es]*")

# %%
units = (ingredients
            .map(lambda x: x.lower())
            .map(lambda x: re.sub("[0-9/,]","",x))
            #.map(lambda x: unit_regex.split(x)[-1].strip())
             
        )

# %%
units.distinct().sorted().list()
# Out:
# ['(  inch thick) center-cut bone-in pork chops',
#  '(  inch thick) pork chops',
#  '(  inch) thick pork chops',
#  '(  pound) beef tri-tip roast',
#  '(  pound) boneless beef chuck roast',
#  '(  pound) boneless pork loin roast',
#  '(  pound) boneless pork shoulder cut into -inch cubes',
#  '(  pound) butternut squash - peeled seeded and cut into -inch chunks',
#  '(  pound) corned beef brisket',
#  '(  pound) eggplant',
#  '(  pound) eggplant halved lengthwise',
#  '(  pound) fully trimmed pork tenderloins cut into  pieces',
#  '(  pound) pork tenderloin',
#  '(  pound) pork tenderloin trimmed of silver skin',
#  '(  pound) uncooked prepared beef veal and pork meatloaf',
#  '( ) pound boneless pork shoulder trimmed and cut into  inch chunks',
#  '( ) pound chicken cut into  pieces',
#  '( ) pound whole chicken at room temperature',
#  '( -pound) beef flank steak',
#  '( -pound) salmon fillet',
#  '( bone) rack of lamb trimmed and frenched',
#  '( count) package hawaiian bread rolls',
#  '( fl oz) bottle balsamic vinaigrette salad dressing',
#  '( fluid ounce) bottle apple juice chilled',
#  '( fluid ounce) bottle beer',
#  '( fluid ounce) bottle dark beer (such as guinness(r))',
#  '( fluid ounce) bottle pina colada mix',
#  '( fluid ounce) bottle russian-style salad dressing',
#  '( fluid ounce) bottle white cranberry juice',
#  '( fluid ounce) bottle white grape juice chilled',
#  '( fluid ounce) bottles beer',
#  '( fluid ounce) bottles cranberry-raspberry juice',
#  '( fluid ounce) bottles fruit punch',
#  '( fluid ounce) can beer',
#  '( fluid ounce) can beer (such as shiner(r) bock)',
#  '( fluid ounce) can chicken broth',
#  '( fluid ounce) can cola-flavored carbonated beverage',
#  '( fluid ounce) can enchilada sauce',
#  '( fluid ounce) can evaporated milk',
#  '( fluid ounce) can frozen cranberry juice concentrate',
#  '( fluid ounce) can frozen limeade concentrate',
#  '( fluid ounce) can frozen pink lemonade concentrate',
#  '( fluid ounce) can frozen pink lemonade concentrate thawed',
#  '( fluid ounce) can light colored beer',
#  '( fluid ounce) can low-sodium vegetable juice',
#  '( fluid ounce) can nestle(r) carnation(r) evaporated milk',
#  '( fluid ounce) can or bottle beer',
#  '( fluid ounce) can or bottle beer room temperature',
#  '( fluid ounce) can or bottle caffeinated citrus-flavored soda (such as mountain dew(r))',
#  '( fluid ounce) can or bottle chile sauce',
#  '( fluid ounce) can or bottle chili sauce',
#  '( fluid ounce) can or bottle cola-flavored carbonated beverage',
#  '( fluid ounce) can or bottle dark beer',
#  '( fluid ounce) can or bottle guinness(r) beer',
#  '( fluid ounce) can or bottle hot chicken wing sauce',
#  '( fluid ounce) can or bottle irish stout beer (e.g. guinness(r))',
#  '( fluid ounce) can or bottle lemon-lime flavored carbonated beverage',
#  '( fluid ounce) can or bottle light beer',
#  '( fluid ounce) can or bottle light beer (such as coors(r))',
#  '( fluid ounce) can or bottle mountain dew (tm)',
#  '( fluid ounce) can or bottle room temperature beer',
#  '( fluid ounce) can or bottle root beer',
#  '( fluid ounce) can or bottle stout beer',
#  '( fluid ounce) can pineapple juice',
#  '( fluid ounce) can pineapple juice chilled',
#  '( fluid ounce) can tomato juice',
#  '( fluid ounce) cans cola-flavored carbonated beverage',
#  '( fluid ounce) cans evaporated milk',
#  '( fluid ounce) cans frozen lemonade concentrate',
#  '( fluid ounce) cans frozen limeade concentrate',
#  '( fluid ounce) cans or bottles beer',
#  '( fluid ounce) cans or bottles root beer',
#  '( fluid ounce) cans pineapple juice',
#  '( fluid ounce) container chicken stock',
#  '( fluid ounce) container liquid pectin',
#  '( g) packages philadelphia brick cream cheese softened',
#  '( inch square) egg roll wrappers',
#  '( inch square) spring roll wrappers',
#  '( inch thick) pork chops',
#  '( inch thick) pork loin chops',
#  '( inch thick) slices day-old french bread',
#  '( inch thick) slices french bread',
#  '( inch thick) slices french bread cut into cubes',
#  '( inch) angel food cake',
#  '( inch) angel food cake cut in cubes',
#  '( inch) baked pastry shell cooled',
#  '( inch) bamboo skewers soaked in water for  hours',
#  '( inch) corn tortillas',
#  '( inch) corn tortillas (optional)',
#  '( inch) corn tortillas coarsely chopped',
#  '( inch) corn tortillas cut in half',
#  '( inch) corn tortillas cut into  inch strips',
#  '( inch) corn tortillas cut into strips',
#  '( inch) corn tortillas quartered',
#  '( inch) corn tortillas torn in half',
#  '( inch) corn tortillas torn into strips',
#  '( inch) corn tortillas warmed',
#  '( inch) cubes colby-jack cheese',
#  '( inch) deep dish frozen pie crust',
#  '( inch) deep dish frozen pie crusts',
#  '( inch) deep dish frozen pie crusts thawed',
#  '( inch) deep dish pie crust',
#  '( inch) flour tortilla',
#  '( inch) flour tortillas',
#  '( inch) flour tortillas cut into -inch pieces',
#  '( inch) flour tortillas cut into strips',
#  '( inch) flour tortillas warmed',
#  '( inch) french bread baguettes split lengthwise',
#  '( inch) french sandwich rolls',
#  '( inch) frozen prepared pie crust thawed',
#  '( inch) frozen prepared pie crusts thawed',
#  '( inch) pie crust baked',
#  '( inch) pie crust baked and cooled',
#  '( inch) pie crusts',
#  '( inch) pie shell',
#  '( inch) pie shell baked',
#  '( inch) pie shells baked',
#  '( inch) piece cinnamon stick',
#  '( inch) piece fresh ginger peeled and chopped',
#  '( inch) piece fresh ginger peeled and thinly sliced',
#  '( inch) piece fresh ginger root chopped',
#  '( inch) piece fresh ginger root grated',
#  '( inch) piece fresh ginger root minced',
#  '( inch) piece fresh ginger root peeled and chopped',
#  '( inch) piece fresh ginger root peeled and grated',
#  '( inch) piece fresh ginger root peeled and minced',
#  '( inch) piece fresh ginger root thinly sliced',
#  '( inch) piece konbu dried kelp (optional)',
#  '( inch) pieces long red vine licorice',
#  '( inch) pre-baked pizza crust',
#  '( inch) pre-baked pizza crusts',
#  '( inch) prepared chocolate cookie crumb crust',
#  '( inch) prepared graham cracker crust',
#  '( inch) prepared graham cracker crusts',
#  '( inch) prepared pizza crust',
#  '( inch) prepared shortbread pie crust',
#  '( inch) refrigerated pie crust',
#  '( inch) refrigerated prerolled pie crusts',
#  '( inch) refrigerator pie crusts',
#  '( inch) sticks cinnamon crushed',
#  '( inch) thick pork chops',
#  '( inch) unbaked  inch pie crust',
#  '( inch) unbaked deep dish pie crust',
#  '( inch) unbaked pie crust',
#  '( inch) unbaked pie crust (see footnote for recipe link)',
#  '( inch) unbaked pie crusts',
#  '( inch) unbaked pie shell',
#  '( inch) unbaked pie shells',
#  '( inch) unbaked tart shells',
#  '( inch) untreated cedar planks',
#  '( inch) whole wheat pita breads',
#  '( inch) whole wheat tortillas',
#  '( inch) wooden skewers or as needed soaked in water for  minutes',
#  '( inch)s french or italian sandwich rolls split',
#  '( inch-thick) boneless pork chops trimmed',
#  '( liter) bottle lemon-lime flavored carbonated beverage',
#  '( liter) bottle lemon-lime flavored carbonated beverage chilled',
#  '( liter) bottles ginger ale chilled',
#  '( liter) bottles lemon-lime flavored carbonated beverage',
#  '( milliliter) bottle champagne',
#  '( milliliter) bottle dry red wine',
#  '( milliliter) bottle dry white wine',
#  '( milliliter) bottle red wine',
#  '( milliliter) bottle rum',
#  '( milliliter) bottle southern comfort liqueur',
#  '( milliliter) bottle white wine chilled',
#  '( milliliter) bottles champagne chilled',
#  '( milliliter) bottles sparkling apple cider',
#  '( or  inch) white cake layers baked and cooled',
#  '( ounce) ( inch thick) filet mignon steaks',
#  '( ounce) (-inch thick) pork chops',
#  '( ounce) ahi tuna steaks',
#  '( ounce) bag baby spinach',
#  '( ounce) bag baby spinach leaves',
#  '( ounce) bag chocolate chips',
#  '( ounce) bag chopped dried mixed fruit',
#  '( ounce) bag coleslaw mix',
#  '( ounce) bag cranberries fresh or frozen',
#  '( ounce) bag fresh spinach',
#  '( ounce) bag fresh spinach chopped',
#  '( ounce) bag fresh spinach torn',
#  '( ounce) bag frozen mexican-style corn',
#  '( ounce) bag frozen mixed vegetables',
#  '( ounce) bag mixed field greens',
#  '( ounce) bag shredded mexican cheese blend',
#  '( ounce) bag small potatoes',
#  '( ounce) bag spinach leaves',
#  '( ounce) bag tortilla chips crushed',
#  '( ounce) bag washed fresh spinach',
#  '( ounce) bag washed spinach leaves',
#  '( ounce) bags clean fresh spinach roughly chopped',
#  '( ounce) bags fresh spinach',
#  '( ounce) bags fresh spinach leaves',
#  '( ounce) bags milk chocolate candy kisses unwrapped',
#  '( ounce) baking potatoes',
#  '( ounce) bar chocolate flavored confectioners coating',
#  '( ounce) beef chuck steaks well trimmed',
#  '( ounce) beef cube steaks',
#  '( ounce) beef eye of round steaks',
#  '( ounce) beef rib eye steaks',
#  '( ounce) beef sirloin steaks',
#  '( ounce) beef sirloin steaks at least  inch thick',
#  '( ounce) beef top sirloin steaks',
#  '( ounce) bone-in chicken thighs with skin',
#  '( ounce) boneless center-cut pork chops',
#  '( ounce) boneless pork loin chops',
#  '( ounce) boneless salmon fillets',
#  '( ounce) boneless skinless chicken breast halves',
#  '( ounce) bottle barbecue sauce',
#  '( ounce) bottle barbeque sauce',
#  "( ounce) bottle barbeque sauce (such as sweet baby ray's(r))",
#  '( ounce) bottle blue cheese dressing',
#  '( ounce) bottle blue cheese salad dressing',
#  '( ounce) bottle caesar salad dressing',
#  '( ounce) bottle catalina salad dressing',
#  '( ounce) bottle chili sauce',
#  '( ounce) bottle clam juice',
#  '( ounce) bottle diced pimento drained',
#  '( ounce) bottle french dressing',
#  '( ounce) bottle hickory smoke barbeque sauce',
#  '( ounce) bottle honey barbecue sauce',
#  '( ounce) bottle hot pepper sauce',
#  '( ounce) bottle hot red pepper sauce',
#  '( ounce) bottle hot sauce',
#  '( ounce) bottle italian dressing',
#  '( ounce) bottle italian salad dressing',
#  '( ounce) bottle italian-style salad dressing',
#  '( ounce) bottle ketchup',
#  '( ounce) bottle lager-style beer',
#  '( ounce) bottle lemon juice concentrate',
#  '( ounce) bottle mccormick(r) red food color',
#  '( ounce) bottle ranch dressing',
#  '( ounce) bottle ranch dressing (optional)',
#  '( ounce) bottle ranch-style salad dressing',
#  '( ounce) bottle russian-style salad dressing',
#  '( ounce) bottle tomato-based chili sauce',
#  '( ounce) bottle your favorite barbecue sauce',
#  '( ounce) bottle zesty italian dressing',
#  '( ounce) bottles barbecue sauce your choice',
#  '( ounce) bottles barbeque sauce',
#  '( ounce) bottles chili sauce',
#  '( ounce) bottles italian-style salad dressing',
#  '( ounce) bottles porter beer room temperature',
#  '( ounce) box chicken-flavored crackers',
#  '( ounce) box chicken-flavored dry bread stuffing mix',
#  "( ounce) box confectioners' sugar",
#  '( ounce) box frozen chopped spinach thawed and drained',
#  '( ounce) box frozen chopped spinach thawed and drained well',
#  '( ounce) box frozen chopped spinach thawed and squeezed dry',
#  '( ounce) box penne pasta',
#  '( ounce) can % pure pumpkin',
#  '( ounce) can ( to  count) artichoke hearts in water drained',
#  '( ounce) can apple pie filling',
#  '( ounce) can artichoke hearts drained',
#  '( ounce) can artichoke hearts drained and chopped',
#  '( ounce) can artichoke hearts drained and sliced',
#  '( ounce) can artichoke hearts in water',
#  '( ounce) can artichoke hearts in water drained and quartered',
#  '( ounce) can asparagus drained',
#  '( ounce) can bacon bits',
#  '( ounce) can baked beans',
#  '( ounce) can baked beans with pork',
#  '( ounce) can bean sprouts drained',
#  '( ounce) can beef broth',
#  '( ounce) can beef consomme',
#  '( ounce) can black bean soup',
#  '( ounce) can black beans',
#  '( ounce) can black beans drained',
#  '( ounce) can black beans drained and rinsed',
#  '( ounce) can black beans rinsed and drained',
#  '( ounce) can black beans rinsed drained',
#  '( ounce) can black beans undrained',
#  '( ounce) can black beans with liquid',
#  '( ounce) can black beans; drain and reserve liquid',
#  '( ounce) can black olives chopped',
#  '( ounce) can black olives drained',
#  '( ounce) can black olives drained and chopped',
#  '( ounce) can black olives drained and sliced',
#  '( ounce) can black olives sliced',
#  '( ounce) can black-eyed peas',
#  '( ounce) can black-eyed peas drained',
#  '( ounce) can butter beans',
#  '( ounce) can butter beans drained',
#  '( ounce) can butter beans undrained',
#  '( ounce) can buttermilk biscuits',
#  '( ounce) can canned chopped green chile peppers',
#  '( ounce) can canned crabmeat drained',
#  '( ounce) can canned cream corn',
#  '( ounce) can canned crushed tomatoes',
#  '( ounce) can canned green chile peppers chopped',
#  '( ounce) can canned kidney beans - drained rinsed and mashed',
#  '( ounce) can canned mushrooms',
#  '( ounce) can canned onions',
#  '( ounce) can canned peeled and diced tomatoes',
#  '( ounce) can canned pumpkin puree',
#  '( ounce) can canned tuna',
#  '( ounce) can cannellini beans',
#  '( ounce) can cannellini beans drained and rinsed',
#  '( ounce) can cannellini beans rinsed and drained',
#  '( ounce) can cannellini beans with liquid',
#  '( ounce) can carrots with juice',
#  '( ounce) can cherry pie filling',
#  '( ounce) can cherry pie filling or flavor of choice',
#  '( ounce) can chicken broth',
#  '( ounce) can chicken chunks drained',
#  '( ounce) can chickpeas',
#  '( ounce) can chickpeas (garbanzo beans) drained',
#  '( ounce) can chickpeas rinsed and drained',
#  '( ounce) can chili',
#  '( ounce) can chili beans',
#  '( ounce) can chili beans drained',
#  '( ounce) can chili beans in spicy sauce',
#  '( ounce) can chili beans undrained',
#  '( ounce) can chili beans with liquid',
#  '( ounce) can chili without beans',
#  '( ounce) can chipotle peppers in adobo sauce',
#  '( ounce) can chipotle peppers in adobo sauce or to taste',
#  '( ounce) can chocolate syrup',
#  '( ounce) can chopped black olives',
#  '( ounce) can chopped black olives drained',
#  '( ounce) can chopped green chile peppers',
#  '( ounce) can chopped green chile peppers drained',
#  '( ounce) can chopped green chiles drained',
#  '( ounce) can chopped green chiles undrained',
#  '( ounce) can chopped green chilies',
#  '( ounce) can chopped green chilies divided',
#  '( ounce) can chopped green chilies drained',
#  '( ounce) can chopped mushrooms with liquid',
#  '( ounce) can chopped spinach drained',
#  '( ounce) can chopped stewed tomatoes',
#  '( ounce) can chunk chicken',
#  '( ounce) can coconut milk',
#  '( ounce) can condensed cream of cheddar cheese soup',
#  '( ounce) can condensed cream of chicken soup',
#  '( ounce) can condensed cream of mushroom soup',
#  '( ounce) can corn',
#  '( ounce) can corn drained',
#  '( ounce) can corned beef cut into chunks',
#  '( ounce) can crab meat drained',
#  '( ounce) can crabmeat - drained flaked and cartilage removed',
#  '( ounce) can crabmeat drained',
#  '( ounce) can crabmeat drained and flaked',
#  '( ounce) can cranberry sauce',
#  '( ounce) can cream of chicken soup',
#  '( ounce) can cream of coconut',
#  '( ounce) can cream style corn',
#  '( ounce) can cream-style corn',
#  '( ounce) can cream-style corn drained',
#  '( ounce) can creamed corn',
#  '( ounce) can crushed italian tomatoes',
#  '( ounce) can crushed pineapple',
#  '( ounce) can crushed pineapple drained',
#  '( ounce) can crushed pineapple drained with juice reserved',
#  '( ounce) can crushed pineapple with juice',
#  '( ounce) can crushed san marzano tomatoes',
#  '( ounce) can crushed san marzano tomatoes or other high-quality plum tomatoes',
#  '( ounce) can crushed tomatoes',
#  '( ounce) can crushed tomatoes (quality varies dramatically; i prefer redpack progresso and muir glen brands)',
#  '( ounce) can crushed tomatoes with liquid',
#  '( ounce) can cut green beans drained',
#  '( ounce) can cut sweet potatoes undrained',
#  '( ounce) can dark red kidney beans',
#  '( ounce) can diced green chile peppers',
#  '( ounce) can diced green chile peppers drained',
#  '( ounce) can diced green chile peppers undrained',
#  '( ounce) can diced green chiles',
#  '( ounce) can diced green chiles drained',
#  '( ounce) can diced green chili peppers',
#  '( ounce) can diced green chilies drained',
#  '( ounce) can diced jalapeno peppers',
#  '( ounce) can diced tomatoes',
#  '( ounce) can diced tomatoes and green chiles',
#  '( ounce) can diced tomatoes and green chiles undrained',
#  '( ounce) can diced tomatoes and green chilies',
#  '( ounce) can diced tomatoes drained',
#  '( ounce) can diced tomatoes with garlic and olive oil',
#  '( ounce) can diced tomatoes with green chile peppers',
#  '( ounce) can diced tomatoes with green chile peppers (such as ro*tel(r))',
#  '( ounce) can diced tomatoes with green chile peppers (such as ro*tel(r)) drained',
#  '( ounce) can diced tomatoes with green chile peppers (such as ro*tel(r)) undrained',
#  '( ounce) can diced tomatoes with green chile peppers drained',
#  '( ounce) can diced tomatoes with green chile peppers with liquid',
#  '( ounce) can diced tomatoes with green chiles (such as ro*tel)',
#  '( ounce) can diced tomatoes with juice',
#  '( ounce) can eagle brand(r) sweetened condensed milk',
#  '( ounce) can eagle brand(r) sweetened condensed milk (not evaporated milk)',
#  '( ounce) can enchilada sauce',
#  '( ounce) can enchilada sauce divided',
#  '( ounce) can evaporated milk',
#  '( ounce) can fat free condensed cream of mushroom soup',
#  '( ounce) can fat-free refried beans',
#  '( ounce) can french fried onions',
#  '( ounce) can french-fried onions',
#  '( ounce) can french-fried onions divided',
#  '( ounce) can frozen lemonade concentrate',
#  '( ounce) can frozen lemonade concentrate thawed',
#  '( ounce) can frozen limeade concentrate',
#  '( ounce) can frozen orange juice concentrate',
#  '( ounce) can fruit cocktail drained',
#  '( ounce) can fully cooked luncheon meat (such as spam(r)) cubed',
#  '( ounce) can garbanzo beans (chickpeas) drained and mashed',
#  '( ounce) can garbanzo beans (chickpeas) drained and rinsed',
#  '( ounce) can garbanzo beans (chickpeas) rinsed and drained',
#  '( ounce) can garbanzo beans drained',
#  '( ounce) can garbanzo beans drained and rinsed',
#  '( ounce) can garbanzo beans drained liquid reserved',
#  '( ounce) can garbanzo beans half the liquid reserved',
#  '( ounce) can garbanzo beans rinsed and drained',
#  '( ounce) can great northern beans drained',
#  '( ounce) can great northern beans drained and rinsed',
#  '( ounce) can green beans',
#  '( ounce) can green beans drained',
#  '( ounce) can green beans drained and rinsed',
#  '( ounce) can green chile enchilada sauce',
#  '( ounce) can green chile peppers chopped',
#  '( ounce) can green enchilada sauce',
#  '( ounce) can green salsa',
#  '( ounce) can italian plum tomatoes',
#  '( ounce) can italian-style diced tomatoes',
#  '( ounce) can italian-style plum tomatoes drained and coarsely chopped',
#  '( ounce) can italian-style whole peeled tomatoes',
#  '( ounce) can jellied cranberry sauce',
#  '( ounce) can kidney beans',
#  '( ounce) can kidney beans drained',
#  '( ounce) can kidney beans drained and rinsed',
#  '( ounce) can kidney beans rinsed and drained',
#  '( ounce) can kidney beans undrained',
#  '( ounce) can kidney beans with liquid',
#  "( ounce) can libby's(r) % pure pumpkin",
#  '( ounce) can light coconut milk',
#  '( ounce) can light red kidney beans',
#  '( ounce) can lima beans drained',
#  '( ounce) can mandarin orange segments',
#  '( ounce) can mandarin orange segments drained',
#  '( ounce) can mandarin oranges drained',
#  '( ounce) can mandarin oranges drained and sliced',
#  '( ounce) can mandarin oranges juice reserved',
#  '( ounce) can marinated artichoke hearts drained and chopped',
#  '( ounce) can marinated quartered artichoke hearts drained liquid reserved',
#  '( ounce) can mexican-style corn',
#  '( ounce) can mexican-style corn drained',
#  '( ounce) can mild chunky salsa',
#  '( ounce) can minced clams drained with juice reserved',
#  '( ounce) can mixed vegetables',
#  '( ounce) can mixed vegetables drained',
#  '( ounce) can mushroom pieces drained',
#  '( ounce) can mushroom stems and pieces drained',
#  '( ounce) can mushrooms drained',
#  '( ounce) can mushrooms drained (optional)',
#  '( ounce) can mushrooms with liquid',
#  '( ounce) can navy beans',
#  '( ounce) can peach pie filling',
#  '( ounce) can peaches',
#  '( ounce) can peas',
#  '( ounce) can peas drained',
#  '( ounce) can peas undrained',
#  '( ounce) can peeled and diced tomatoes',
#  '( ounce) can peeled and diced tomatoes with juice',
#  '( ounce) can pillsbury(r) refrigerated crescent dinner rolls',
#  '( ounce) can pineapple chunks',
#  '( ounce) can pineapple chunks - drained with juice reserved',
#  '( ounce) can pineapple chunks drained',
#  '( ounce) can pineapple chunks drained (juice reserved)',
#  '( ounce) can pineapple chunks drained with juice reserved',
#  '( ounce) can pineapple chunks juice reserved',
#  '( ounce) can pineapple chunks reserve juice',
#  '( ounce) can pineapple chunks undrained',
#  '( ounce) can pineapple juice',
#  '( ounce) can pineapple tidbits drained',
#  '( ounce) can pineapple tidbits drained with juice reserved',
#  '( ounce) can pineapple tidbits undrained',
#  '( ounce) can pinto beans',
#  '( ounce) can pinto beans drained',
#  '( ounce) can pinto beans drained and rinsed',
#  '( ounce) can pinto beans undrained',
#  '( ounce) can pitted black olives',
#  '( ounce) can pizza sauce',
#  '( ounce) can pork and beans',
#  '( ounce) can pumpkin',
#  "( ounce) can pumpkin pie filling (such as libby's(r))",
#  '( ounce) can pumpkin puree',
#  '( ounce) can quartered marinated artichoke hearts drained',
#  '( ounce) can ranch-style beans',
#  '( ounce) can red enchilada sauce',
#  '( ounce) can red kidney beans drained',
#  '( ounce) can refried beans',
#  '( ounce) can refrigerated biscuit dough',
#  '( ounce) can refrigerated biscuit dough (such as pillsbury grands!(r))',
#  '( ounce) can refrigerated biscuit dough separated and cut into six pieces',
#  '( ounce) can refrigerated buttermilk biscuit dough',
#  '( ounce) can refrigerated crescent roll dough',
#  '( ounce) can refrigerated crescent rolls',
#  '( ounce) can refrigerated flaky biscuit dough',
#  '( ounce) can refrigerated jumbo buttermilk biscuits',
#  '( ounce) can refrigerated layered biscuits',
#  '( ounce) can refrigerated pizza crust',
#  '( ounce) can refrigerated pizza crust dough',
#  '( ounce) can salmon drained and flaked',
#  '( ounce) can salsa',
#  '( ounce) can sauerkraut drained',
#  '( ounce) can sauerkraut drained and pressed dry',
#  '( ounce) can seasoned black beans',
#  '( ounce) can shredded bamboo shoots',
#  '( ounce) can shrimp drained',
#  '( ounce) can sliced beets with liquid',
#  '( ounce) can sliced black olives',
#  '( ounce) can sliced black olives (optional)',
#  '( ounce) can sliced black olives drained',
#  '( ounce) can sliced black olives drained (optional)',
#  '( ounce) can sliced canned peaches drained',
#  '( ounce) can sliced mushrooms',
#  '( ounce) can sliced mushrooms drained',
#  '( ounce) can sliced peaches',
#  '( ounce) can sliced peaches drained',
#  '( ounce) can sliced peaches drained and syrup reserved',
#  '( ounce) can sliced peaches in light syrup',
#  '( ounce) can sliced pineapple',
#  '( ounce) can sliced pineapple drained with juice reserved',
#  '( ounce) can sliced pineapple in juice drained - divided',
#  '( ounce) can sliced potatoes with juice',
#  '( ounce) can sliced water chestnuts drained',
#  '( ounce) can solid pack pumpkin',
#  '( ounce) can solid pack pumpkin puree',
#  '( ounce) can solid white tuna packed in water drained',
#  '( ounce) can stewed diced tomatoes',
#  '( ounce) can stewed tomatoes',
#  '( ounce) can stewed tomatoes drained and sliced',
#  '( ounce) can stewed tomatoes with juice',
#  '( ounce) can stewed tomatoes with juice chopped',
#  '( ounce) can sweet corn drained',
#  '( ounce) can sweet potatoes',
#  '( ounce) can sweetened condensed milk',
#  '( ounce) can sweetened cream of coconut',
#  '( ounce) can tomatillo salsa',
#  '( ounce) can tomatillos',
#  '( ounce) can tomato paste',
#  '( ounce) can tomato paste or to taste',
#  '( ounce) can tomato puree',
#  '( ounce) can tomato sauce',
#  "( ounce) can tomato sauce (such as hunt's(r))",
#  '( ounce) can tomato sauce divided',
#  '( ounce) can tomato sauce with garlic and onions',
#  '( ounce) can tomato sauce with no salt added',
#  '( ounce) can tuna',
#  '( ounce) can tuna drained',
#  '( ounce) can unsweetened coconut milk',
#  '( ounce) can unsweetened pineapple chunks',
#  '( ounce) can vegetable broth',
#  '( ounce) can vegetarian baked beans',
#  '( ounce) can water chestnuts',
#  '( ounce) can water chestnuts drained',
#  '( ounce) can water chestnuts drained (optional)',
#  '( ounce) can water chestnuts drained and chopped',
#  '( ounce) can water chestnuts drained and finely chopped',
#  '( ounce) can water chestnuts drained and sliced',
#  '( ounce) can water chestnuts halved',
#  '( ounce) can white beans',
#  '( ounce) can white beans drained',
#  '( ounce) can white corn drained',
#  '( ounce) can white hominy drained',
#  '( ounce) can white kidney or cannellini beans drained',
#  '( ounce) can white tuna drained and flaked',
#  '( ounce) can whole berry cranberry sauce',
#  '( ounce) can whole black olives',
#  '( ounce) can whole cranberry sauce',
#  '( ounce) can whole italian plum tomatoes (such as san marzano) crushed',
#  '( ounce) can whole kernel corn',
#  '( ounce) can whole kernel corn drained',
#  '( ounce) can whole kernel corn drained (optional)',
#  '( ounce) can whole kernel corn drained and  liquid reserved',
#  '( ounce) can whole kernel corn undrained',
#  '( ounce) can whole kernel corn with liquid',
#  '( ounce) can whole new potatoes drained',
#  '( ounce) can whole niblet style corn',
#  '( ounce) can whole peeled tomatoes',
#  '( ounce) can whole peeled tomatoes chopped',
#  '( ounce) can whole peeled tomatoes chopped juice reserved',
#  '( ounce) can whole peeled tomatoes crushed',
#  '( ounce) can whole peeled tomatoes mashed',
#  '( ounce) can whole peeled tomatoes with juice',
#  '( ounce) can whole peeled tomatoes with liquid chopped',
#  '( ounce) can yellow corn drained',
#  '( ounce) cans apple pie filling',
#  '( ounce) cans artichoke hearts drained and chopped',
#  '( ounce) cans baked beans',
#  '( ounce) cans baked beans with pork',
#  '( ounce) cans beef broth',
#  '( ounce) cans beer',
#  '( ounce) cans black beans',
#  '( ounce) cans black beans drained',
#  '( ounce) cans black beans drained and rinsed',
#  '( ounce) cans black beans rinsed and drained',
#  '( ounce) cans black beans undrained',
#  '( ounce) cans black-eyed peas drained',
#  '( ounce) cans canned green chile peppers chopped',
#  '( ounce) cans canned kidney beans drained',
#  '( ounce) cans cannellini (white kidney) beans rinsed and drained',
#  '( ounce) cans cannellini beans',
#  '( ounce) cans cannellini beans rinsed and drained',
#  '( ounce) cans chicken broth',
#  '( ounce) cans chicken chunks',
#  '( ounce) cans chili beans',
#  '( ounce) cans chili beans drained',
#  '( ounce) cans chili beans undrained',
#  '( ounce) cans chili with beans',
#  '( ounce) cans chopped green chile peppers',
#  '( ounce) cans chopped green chile peppers drained',
#  '( ounce) cans chopped green chiles',
#  '( ounce) cans chopped green chilies',
#  '( ounce) cans chunk chicken',
#  '( ounce) cans chunk chicken drained',
#  '( ounce) cans coconut milk',
#  '( ounce) cans condensed cream of cheddar cheese soup',
#  '( ounce) cans condensed cream of chicken soup',
#  '( ounce) cans crabmeat',
#  '( ounce) cans crabmeat drained and flaked',
#  '( ounce) cans crescent roll dough',
#  '( ounce) cans crushed tomatoes',
#  '( ounce) cans cut green beans drained',
#  '( ounce) cans dark red kidney beans',
#  "( ounce) cans dark red kidney beans (such as bush's(r))",
#  '( ounce) cans diced green chile peppers',
#  '( ounce) cans diced green chile peppers drained',
#  '( ounce) cans diced green chiles',
#  '( ounce) cans diced green chilies drained',
#  '( ounce) cans diced tomatoes',
#  '( ounce) cans diced tomatoes with green chile peppers',
#  '( ounce) cans diced tomatoes with green chile peppers (such as ro*tel(r))',
#  '( ounce) cans diced tomatoes with green chile peppers partially drained',
#  '( ounce) cans diced tomatoes with green chilies undrained',
#  '( ounce) cans diced tomatoes with juice',
#  '( ounce) cans diced tomatoes with liquid',
#  '( ounce) cans enchilada sauce',
#  '( ounce) cans evaporated milk',
#  '( ounce) cans fat-free chicken broth',
#  '( ounce) cans garbanzo beans',
#  '( ounce) cans garbanzo beans (chickpeas) drained and rinsed',
#  '( ounce) cans garbanzo beans drained',
#  '( ounce) cans goya tomato sauce',
#  '( ounce) cans great northern beans rinsed and drained',
#  '( ounce) cans great northern beans undrained',
#  '( ounce) cans green beans',
#  '( ounce) cans green beans drained',
#  '( ounce) cans green salsa',
#  '( ounce) cans hot tomato sauce',
#  '( ounce) cans italian-style diced tomatoes drained',
#  '( ounce) cans jalapeno salsa',
#  '( ounce) cans kidney beans',
#  '( ounce) cans kidney beans drained',
#  '( ounce) cans kidney beans drained and rinsed',
#  '( ounce) cans kidney beans rinsed and drained',
#  '( ounce) cans mandarin orange segments drained',
#  '( ounce) cans mandarin oranges drained',
#  '( ounce) cans mexican-style corn drained',
#  '( ounce) cans minced clams',
#  '( ounce) cans mixed vegetables drained',
#  '( ounce) cans organic vegetable broth',
#  '( ounce) cans peaches in heavy syrup',
#  '( ounce) cans peeled and diced tomatoes',
#  '( ounce) cans pineapple tidbits drained',
#  '( ounce) cans pinto beans',
#  '( ounce) cans pinto beans drained',
#  '( ounce) cans pinto beans drained and rinsed',
#  '( ounce) cans pitted bing cherries drained',
#  '( ounce) cans pitted sour cherries',
#  '( ounce) cans prepared green chile salsa',
#  '( ounce) cans red kidney beans drained',
#  '( ounce) cans refried beans',
#  '( ounce) cans refrigerated crescent dinner rolls',
#  '( ounce) cans refrigerated crescent roll dough',
#  '( ounce) cans refrigerated crescent rolls',
#  '( ounce) cans salmon',
#  '( ounce) cans sliced black olives',
#  '( ounce) cans sliced mushrooms drained',
#  '( ounce) cans sliced mushrooms with juice',
#  '( ounce) cans sliced peaches in heavy syrup',
#  '( ounce) cans stewed tomatoes',
#  '( ounce) cans sweet potatoes drained and mashed',
#  '( ounce) cans tomatillos drained and chopped',
#  '( ounce) cans tomato paste',
#  '( ounce) cans tomato sauce',
#  '( ounce) cans tomato sauce divided',
#  '( ounce) cans tuna drained',
#  '( ounce) cans tuna drained and flaked',
#  '( ounce) cans vegetable broth',
#  '( ounce) cans water chestnuts',
#  '( ounce) cans white beans',
#  '( ounce) cans white beans drained',
#  '( ounce) cans white beans such as cannellini or navy undrained',
#  '( ounce) cans white kidney beans (cannellini) rinsed and drained',
#  '( ounce) cans white kidney beans rinsed and drained',
#  '( ounce) cans whole green chile peppers drained',
#  '( ounce) cans whole green chili peppers drained and sliced lengthwise',
#  '( ounce) cans whole kernel corn drained',
#  '( ounce) cans whole peeled san marzano tomatoes',
#  '( ounce) cans whole peeled tomatoes',
#  '( ounce) cans whole peeled tomatoes crushed',
#  '( ounce) cans whole peeled tomatoes drained',
#  '( ounce) cans whole peeled tomatoes with liquid',
#  '( ounce) carton chicken broth',
#  '( ounce) carton egg substitute',
#  '( ounce) cartons fat-free low-sodium chicken broth',
#  '( ounce) center-cut salmon fillets with skin',
#  '( ounce) container alfredo-style pasta sauce',
#  '( ounce) container blueberry flavored yogurt',
#  '( ounce) container chive and onion cream cheese',
#  '( ounce) container coconut pecan frosting',
#  '( ounce) container cottage cheese',
#  '( ounce) container cream cheese frosting',
#  '( ounce) container fat free cream cheese',
#  '( ounce) container fat free sour cream',
#  '( ounce) container fat-free plain yogurt',
#  '( ounce) container fresh mozzarella cheese diced',
#  '( ounce) container frozen apple cider concentrate undiluted',
#  '( ounce) container frozen light whipped topping thawed',
#  '( ounce) container frozen non-dairy whipped topping',
#  '( ounce) container frozen whipped topping thawed',
#  '( ounce) container frozen whipped topping thawed divided',
#  '( ounce) container garlic-herb flavored cheese spread',
#  '( ounce) container honey mustard salad dressing',
#  '( ounce) container light sour cream',
#  '( ounce) container low-fat cottage cheese',
#  '( ounce) container low-fat ricotta cheese',
#  '( ounce) container mascarpone cheese',
#  '( ounce) container mexican crema crema fresca',
#  '( ounce) container nonfat sour cream',
#  '( ounce) container part-skim ricotta cheese',
#  '( ounce) container peach yogurt',
#  '( ounce) container plain greek-style yogurt',
#  '( ounce) container plain low-fat yogurt',
#  '( ounce) container plain yogurt',
#  '( ounce) container polly-o original ricotta cheese',
#  '( ounce) container prepared chocolate frosting',
#  '( ounce) container raspberries barely moistened and rolled in about',
#  '( ounce) container reduced fat sour cream',
#  '( ounce) container ricotta cheese',
#  '( ounce) container small curd cottage cheese',
#  '( ounce) container sour cream',
#  '( ounce) container sour cream (optional)',
#  '( ounce) container tofu',
#  '( ounce) container vanilla low-fat yogurt',
#  '( ounce) container vanilla yogurt',
#  '( ounce) containers alfredo sauce divided',
#  '( ounce) containers chive and onion cream cheese',
#  '( ounce) containers cottage cheese',
#  '( ounce) containers fresh shucked oysters undrained',
#  '( ounce) containers plain yogurt',
#  '( ounce) containers refrigerated soft bread stick dough',
#  '( ounce) containers sour cream',
#  '( ounce) containers whole milk ricotta cheese',
#  '( ounce) country style pork ribs',
#  '( ounce) cube steaks',
#  '( ounce) cube steaks (pounded round meat)',
#  '( ounce) delmonico (rib-eye) steaks',
#  '( ounce) envelope dry onion soup mix',
#  '( ounce) envelope instant hot chocolate mix',
#  '( ounce) envelope ranch salad dressing mix',
#  '( ounce) envelope reduced-sodium taco seasoning mix',
#  '( ounce) envelopes onion soup mix',
#  '( ounce) envelopes ranch dressing mix',
#  '( ounce) filet mignon steaks',
#  '( ounce) fillets beef tenderloin',
#  '( ounce) fillets catfish',
#  '( ounce) fillets cod',
#  '( ounce) fillets cod cut in half',
#  '( ounce) fillets filet mignon',
#  '( ounce) fillets grouper',
#  '( ounce) fillets halibut',
#  '( ounce) fillets mahi mahi fillets',
#  '( ounce) fillets mahi mahi fillets rinsed and patted dry',
#  '( ounce) fillets orange roughy',
#  '( ounce) fillets red snapper',
#  '( ounce) fillets salmon',
#  '( ounce) fillets sea bass',
#  '( ounce) fillets sole',
#  '( ounce) fillets swai fish',
#  '( ounce) fillets tilapia',
#  '( ounce) fillets tilapia (bream)',
#  '( ounce) fillets tilapia fillets',
#  '( ounce) fillets tilapia halved',
#  '( ounce) fillets trout',
#  '( ounce) fresh salmon fillets',
#  '( ounce) fresh tilapia fillets',
#  '( ounce) fresh tuna steaks  inch thick',
#  '( ounce) halibut fillets',
#  '( ounce) halibut steaks',
#  '( ounce) jar alfredo sauce',
#  '( ounce) jar apricot preserves',
#  '( ounce) jar bottled marinara sauce',
#  '( ounce) jar capers liquid reserved',
#  '( ounce) jar caramel ice cream topping',
#  '( ounce) jar caramel topping',
#  '( ounce) jar chocolate fudge topping room temperature',
#  '( ounce) jar chocolate-hazelnut spread such as nutella(r)',
#  '( ounce) jar chunky salsa',
#  '( ounce) jar clam juice',
#  '( ounce) jar diced pimento drained',
#  '( ounce) jar diced pimento peppers drained',
#  '( ounce) jar diced pimentos drained',
#  '( ounce) jar dill pickle slices',
#  '( ounce) jar dried beef',
#  '( ounce) jar garlic-and-tomato pasta sauce',
#  '( ounce) jar grape jelly',
#  '( ounce) jar green salsa (salsa verde)',
#  '( ounce) jar green salsa (such as frontera(r))',
#  '( ounce) jar maraschino cherries',
#  '( ounce) jar maraschino cherries drained',
#  '( ounce) jar maraschino cherries drained (optional)',
#  '( ounce) jar maraschino cherries halved',
#  '( ounce) jar marinara sauce',
#  '( ounce) jar marinated artichoke hearts drained and chopped',
#  '( ounce) jar marshmallow creme',
#  '( ounce) jar mayonnaise',
#  '( ounce) jar meatless spaghetti sauce',
#  '( ounce) jar medium salsa',
#  '( ounce) jar oil-packed sun-dried tomatoes chopped',
#  '( ounce) jar oil-packed sun-dried tomatoes drained and sliced',
#  '( ounce) jar pasta sauce',
#  '( ounce) jar peanut butter',
#  '( ounce) jar pepperoncini',
#  '( ounce) jar pepperoncini juice',
#  '( ounce) jar pepperoncini peppers',
#  '( ounce) jar pepperoncini sliced',
#  '( ounce) jar pesto sauce',
#  '( ounce) jar picante sauce',
#  '( ounce) jar picante sauce divided',
#  '( ounce) jar pimento-stuffed green olives',
#  '( ounce) jar pimentos',
#  '( ounce) jar pimentos drained',
#  '( ounce) jar pizza sauce',
#  '( ounce) jar process cheese sauce',
#  '( ounce) jar quartered marinated artichoke hearts with liquid',
#  '( ounce) jar raspberry preserves',
#  '( ounce) jar real bacon bits',
#  '( ounce) jar roasted red bell peppers',
#  '( ounce) jar roasted red bell peppers drained',
#  '( ounce) jar roasted red peppers',
#  '( ounce) jar roasted red peppers drained and chopped',
#  '( ounce) jar roasted red peppers drained and diced',
#  '( ounce) jar roasted red peppers drained cut into thin strips',
#  '( ounce) jar salsa',
#  '( ounce) jar salsa divided',
#  '( ounce) jar sauerkraut drained',
#  '( ounce) jar sausage flavored spaghetti sauce',
#  '( ounce) jar sliced dill pickles drained',
#  '( ounce) jar sliced mushrooms drained',
#  '( ounce) jar sliced pimento peppers drained',
#  '( ounce) jar sofrito',
#  '( ounce) jar spaghetti sauce',
#  '( ounce) jar spaghetti sauce (such as classico(r) cabernet marinara with herbs)',
#  '( ounce) jar strawberry glaze',
#  '( ounce) jar sun-dried tomatoes packed in oil',
#  '( ounce) jar taco sauce',
#  '( ounce) jar tomato pasta sauce',
#  '( ounce) jar vodka marinara sauce',
#  '( ounce) jars alfredo-style pasta sauce',
#  '( ounce) jars clam juice',
#  '( ounce) jars marinara sauce',
#  '( ounce) jars marshmallow creme',
#  '( ounce) jars pasta sauce',
#  '( ounce) jars pizza sauce',
#  '( ounce) jars prepared pasta sauce',
#  '( ounce) jars spaghetti sauce',
#  '( ounce) jars spaghetti sauce divided',
#  '( ounce) jars tomato basil pasta sauce',
#  '( ounce) jars tomato-basil pasta sauce',
#  '( ounce) lamb loin chops (-inch thick)',
#  '( ounce) links fresh italian sausage',
#  '( ounce) links sweet italian sausage',
#  '( ounce) links sweet italian sausage sliced',
#  '( ounce) loaf crusty french bread cut into bite-size pieces or as needed',
#  '( ounce) lobster tails',
#  '( ounce) mahi mahi fillets',
#  '( ounce) package  bean mixture soaked overnight',
#  '( ounce) package acini di pepe pasta',
#  '( ounce) package angel food cake mix',
#  '( ounce) package angel hair pasta',
#  '( ounce) package baby carrots',
#  '( ounce) package baby spinach leaves',
#  '( ounce) package baby spinach leaves finely chopped',
#  '( ounce) package bacon cut into small pieces',
#  '( ounce) package beef cocktail wieners',
#  '( ounce) package beef frankfurters',
#  '( ounce) package beef kielbasa diced into bite size pieces',
#  '( ounce) package bow tie (farfalle) pasta',
#  '( ounce) package bow tie pasta',
#  '( ounce) package bow-tie pasta (farfalle)',
#  '( ounce) package broccoli coleslaw mix',
#  '( ounce) package brown sugar',
#  '( ounce) package brownie mix',
#  '( ounce) package butterscotch chips',
#  '( ounce) package button mushrooms chopped',
#  '( ounce) package button mushrooms sliced',
#  '( ounce) package candy-coated milk chocolate pieces',
#  '( ounce) package cavatelli pasta',
#  '( ounce) package cheddar cheese',
#  '( ounce) package cheddar cheese cut into  inch slices',
#  '( ounce) package cheddar cheese shredded',
#  '( ounce) package cheese tortellini',
#  '( ounce) package cheese-filled tortellini',
#  '( ounce) package cherry jell-o(r)',
#  '( ounce) package chicken flavored ramen noodles',
#  '( ounce) package chicken flavored ramen noodles crushed seasoning packet reserved',
#  '( ounce) package chicken-flavor stuffing mix',
#  '( ounce) package chocolate frosting',
#  '( ounce) package chocolate graham crackers',
#  '( ounce) package chocolate sandwich cookies',
#  '( ounce) package chocolate sandwich cookies with creme filling',
#  '( ounce) package chopped frozen broccoli thawed',
#  '( ounce) package chopped frozen broccoli thawed and drained',
#  '( ounce) package chopped frozen spinach thawed and squeezed dry',
#  '( ounce) package chopped romaine lettuce',
#  '( ounce) package chow mein noodles',
#  '( ounce) package cold cream cheese cubed',
#  '( ounce) package coleslaw mix',
#  "( ounce) package confectioners' sugar",
#  '( ounce) package cooked egg noodles',
#  '( ounce) package corn bread mix',
#  '( ounce) package corn bread muffin mix',
#  '( ounce) package corn chips',
#  '( ounce) package corn muffin mix',
#  '( ounce) package corn tortilla chips',
#  '( ounce) package corn tortillas',
#  '( ounce) package cottage cheese',
#  '( ounce) package cream cheese',
#  '( ounce) package cream cheese at room temperature',
#  '( ounce) package cream cheese cold',
#  '( ounce) package cream cheese cubed',
#  '( ounce) package cream cheese cut into  inch slices',
#  '( ounce) package cream cheese cut into cubes',
#  '( ounce) package cream cheese diced',
#  '( ounce) package cream cheese diced and softened',
#  '( ounce) package cream cheese room temperature',
#  '( ounce) package cream cheese sliced',
#  '( ounce) package cream cheese softened',
#  '( ounce) package cream-filled chocolate sandwich cookies (such as oreo(r))',
#  '( ounce) package creamed cottage cheese',
#  '( ounce) package crispy chow mein noodles',
#  '( ounce) package crispy corn and rice cereal',
#  '( ounce) package crumbled feta cheese',
#  '( ounce) package dirty rice mix',
#  '( ounce) package ditalini pasta',
#  '( ounce) package double crust ready-to-use pie crust (such as pillsbury(r))',
#  '( ounce) package dried corn husks',
#  '( ounce) package dried flat rice noodles',
#  '( ounce) package dried navy beans',
#  '( ounce) package dried penne pasta',
#  '( ounce) package dried rice noodles',
#  '( ounce) package dry bread stuffing mix',
#  '( ounce) package dry corn bread mix',
#  '( ounce) package dry egg noodles',
#  '( ounce) package dry fettuccine noodles',
#  '( ounce) package dry fiesta-style ranch dressing mix',
#  '( ounce) package dry italian salad dressing mix',
#  '( ounce) package dry lentils',
#  '( ounce) package dry lentils rinsed',
#  '( ounce) package dry linguini',
#  '( ounce) package dry onion soup mix',
#  '( ounce) package dry pasta',
#  '( ounce) package dry pectin',
#  '( ounce) package dry penne pasta',
#  '( ounce) package dry ranch salad dressing mix',
#  '( ounce) package dry ranch-style dressing mix',
#  '( ounce) package dry ziti pasta',
#  '( ounce) package egg noodles',
#  '( ounce) package egg noodles cooked and drained',
#  '( ounce) package egg roll wrappers',
#  '( ounce) package elbow macaroni',
#  '( ounce) package extra firm tofu',
#  '( ounce) package extra firm tofu diced',
#  '( ounce) package extra-firm tofu drained and cubed',
#  '( ounce) package extra-firm tofu drained and pressed',
#  '( ounce) package farfalle (bow tie) pasta',
#  '( ounce) package farfalle pasta',
#  '( ounce) package feta cheese crumbled',
#  '( ounce) package fettuccine pasta',
#  '( ounce) package fettuccini pasta',
#  '( ounce) package firm tofu',
#  '( ounce) package firm tofu cubed',
#  '( ounce) package firm tofu cut into  inch cubes',
#  '( ounce) package firm tofu cut into  inch strips',
#  '( ounce) package firm tofu drained and cubed',
#  '( ounce) package firm tofu drained and cut into strips',
#  '( ounce) package flaked coconut',
#  '( ounce) package fresh brussels sprouts trimmed and sliced',
#  '( ounce) package fresh cranberries',
#  '( ounce) package fresh fettuccine',
#  '( ounce) package fresh green beans',
#  '( ounce) package fresh mozzarella cheese cut into -inch slices',
#  '( ounce) package fresh mushrooms',
#  '( ounce) package fresh mushrooms coarsely chopped',
#  '( ounce) package fresh mushrooms sliced',
#  '( ounce) package fresh mushrooms stems removed',
#  '( ounce) package fresh mushrooms thinly sliced',
#  '( ounce) package fresh spinach leaves',
#  '( ounce) package frozen baby lima beans',
#  '( ounce) package frozen bite-size potato nuggets (such as tater tots(r)) divided',
#  '( ounce) package frozen blackberries',
#  '( ounce) package frozen blueberries',
#  '( ounce) package frozen broccoli',
#  ...]
